# %%
import numpy as np
import os
import glob
import random
import matplotlib.pyplot as plt

# %%
from glob import glob

folders = np.sort( np.array(glob(r'C:\Users\Lenovo\Desktop\CV_Assignment1\data\*'))) 
len(path)
# Out:
# 6

# %%
def image_and_label(folders):

    img = list()
    lb = list()

    for j in range(len(folders)//1):
        v1 = np.sort( np.array(glob( folders[j]+'/*')))
        random.shuffle(v1)

        for i in range(len(v1)//1):

            img.append(v1[i])
            lb.append(j)


    return np.array(img),np.array(lb)

# %%
images,label = image_and_label(folders)

# %%
for i in range(len(images)):
  print(images[i],label[i])
# Out:
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_334.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_298.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_37.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_190.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_188.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_192.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_261.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_78.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_73.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_39.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_107.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_320.JPEG 0
# C:\Users\Lenovo\Desktop\CV_Assignment1\data\n01440764\n01440764_297.JPEG 0
# ...

# %%
image = plt.imread(images[5])
plt.imshow(image)
